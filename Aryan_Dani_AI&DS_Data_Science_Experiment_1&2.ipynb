# %% [markdown]
# # **EXPRIMENT 1:**
# Loading and merging data sets using UCI ML repository.
#
# *   Loading
# *   Merging
# *   Flitering
# *   Sampeling

# %% [markdown]
# import statements

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# LOADING FILES INTO GOOGLE COLLAB

# %%
df1 = pd.read_csv('student3.csv');
df2 = pd.read_csv("Student_5.csv")
df1
df2
# Out:
#     roll     name class  marks     age
# 0      1     anil    TE   56.77   22.0
# 1      2     amit    TE   59.77   21.0
# 2      3   aniket    BE   76.88   19.0
# 3      4  ajinkya    TE   69.66   20.0
# 4      5     asha    TE   63.28    NaN
# 5      6   ayesha    BE     NaN   20.0
# 6      7     amar    BE   65.34   19.0
# 7      7     amar    BE   65.34   19.0
# 8      8    Amita    be  168.33   23.0
# 9      9     amol    TE   56.75   20.0
# 10    10    anmol    BE   78.66    NaN
# 11    11   surbhi    TE     NaN   23.0
# 12    12    Sujay    TE   74.12   22.0
# 13    13  subhash    be   88.45  121.0
# 14    14   sachin   NaN   59.33   21.0
# 15    15  shalini    TE   63.45   20.0

# %% [markdown]
# MERGING BOTH DATASETS

# %%
merged = pd.merge(df1, df2, on='age')
merged
# Out:
#     roll_x   name_x class_x  marks _x   age  roll_y   name_y class_y  marks _y
# 0        1     anil      TE     56.77  22.0       1     anil      TE     56.77
# 1        1     anil      TE     56.77  22.0      12    Sujay      TE     74.12
# 2       12    Sujay      TE     74.12  22.0       1     anil      TE     56.77
# 3       12    Sujay      TE     74.12  22.0      12    Sujay      TE     74.12
# 4        2     amit      TE     59.77  21.0       2     amit      TE     59.77
# 5        2     amit      TE     59.77  21.0      14   sachin     NaN     59.33
# 6       13  subhash      be     88.45  21.0       2     amit      TE     59.77
# 7       13  subhash      be     88.45  21.0      14   sachin     NaN     59.33
# 8       14   sachin     NaN     59.33  21.0       2     amit      TE     59.77
# 9       14   sachin     NaN     59.33  21.0      14   sachin     NaN     59.33
# 10       3   aniket      BE     76.88  19.0       3   aniket      BE     76.88
# ...

# %% [markdown]
# FILTERING OF DATA ON TWO PARAMETERS

# %%
merged.filter(["name_x","name_y"])
# Out:
#      name_x   name_y
# 0      anil     anil
# 1      anil    Sujay
# 2     Sujay     anil
# 3     Sujay    Sujay
# 4      amit     amit
# 5      amit   sachin
# 6   subhash     amit
# 7   subhash   sachin
# 8    sachin     amit
# 9    sachin   sachin
# 10   aniket   aniket
# 11   aniket     amar
# 12   aniket     amar
# 13     amar   aniket
# 14     amar     amar
# 15     amar     amar
# 16  ajinkya  ajinkya
# 17  ajinkya   ayesha
# 18  ajinkya     amol
# 19  ajinkya  shalini
# 20   ayesha  ajinkya
# 21   ayesha   ayesha
# 22   ayesha     amol
# 23   ayesha  shalini
# 24     amol  ajinkya
# 25     amol   ayesha
# 26     amol     amol
# 27     amol  shalini
# 28     amol  ajinkya
# 29     amol   ayesha
# 30     amol     amol
# 31     amol  shalini
# 32  shalini  ajinkya
# 33  shalini   ayesha
# 34  shalini     amol
# 35  shalini  shalini
# 36     asha     asha
# 37     asha    anmol
# 38    anmol     asha
# 39    anmol    anmol
# 40    Amita    Amita
# 41    Amita   surbhi
# ...

# %% [markdown]
# SAMPLING OF DATASETS

# %%
merged.sample(frac =.69)
# Out:
#     roll_x   name_x class_x  marks _x   age  roll_y   name_y class_y  marks _y
# 9       14   sachin     NaN     59.33  21.0      14   sachin     NaN     59.33
# 1        1     anil      TE     56.77  22.0      12    Sujay      TE     74.12
# 29       9     amol      TE     56.75  20.0       6   ayesha      BE       NaN
# 8       14   sachin     NaN     59.33  21.0       2     amit      TE     59.77
# 41       8    Amita      be     68.33  23.0      11   surbhi      TE       NaN
# 42      11   surbhi      TE       NaN  23.0       8    Amita      be    168.33
# 37       5     asha      TE     63.28   NaN      10    anmol      BE     78.66
# 21       6   ayesha      BE       NaN  20.0       6   ayesha      BE       NaN
# 11       3   aniket      BE     76.88  19.0       7     amar      BE     65.34
# 6       13  subhash      be     88.45  21.0       2     amit      TE     59.77
# 39      10    anmol      BE     78.66   NaN      10    anmol      BE     78.66
# ...

# %% [markdown]
# **EXPERIMENT 2**
# ---
# *   Data Preprocessing-Cleaning the data set using data set obtained from UCI ML repository

# %% [markdown]
# Importing essential libraries

# %%
import numpy as np
import pandas as pd
from sklearn.preprocessing import MinMaxScaler, StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error

# %%
df = pd.read_csv('student3.csv')
df
# Out:
#     roll     name class  marks    age
# 0      1     anil    TE   56.77  22.0
# 1      2     amit    TE   59.77  21.0
# 2      3   aniket    BE   76.88  19.0
# 3      4  ajinkya    TE   69.66  20.0
# 4      5     asha    TE   63.28   NaN
# 5      6   ayesha    BE     NaN  20.0
# 6      7     amar    BE   65.34  19.0
# 7      8    Amita    be   68.33  23.0
# 8      9     amol    TE   56.75  20.0
# 9      9     amol    TE   56.75  20.0
# 10    10    anmol    BE   78.66   NaN
# 11    11   surbhi    TE     NaN  23.0
# 12    12    Sujay    TE   74.12  22.0
# 13    13  subhash    be   88.45  21.0
# 14    14   sachin   NaN   59.33  21.0
# 15    15  shalini    TE   63.45  20.0

# %% [markdown]
# Data Inspection

# %%
df.head()
df.info()
df.describe()
df.isnull()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16 entries, 0 to 15
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   roll    16 non-null     int64
#  1   name    16 non-null     object
#  2   class   15 non-null     object
#  3   marks   14 non-null     float64
#  4   age     14 non-null     float64
# dtypes: float64(2), int64(1), object(2)
# memory usage: 768.0+ bytes
#      roll   name  class  marks     age
# 0   False  False  False   False  False
# 1   False  False  False   False  False
# 2   False  False  False   False  False
# 3   False  False  False   False  False
# 4   False  False  False   False   True
# 5   False  False  False    True  False
# 6   False  False  False   False  False
# 7   False  False  False   False  False
# 8   False  False  False   False  False
# 9   False  False  False   False  False
# 10  False  False  False   False   True
# 11  False  False  False    True  False
# ...

# %%
df.dropna()
# Out:
#     roll     name class  marks    age
# 0      1     anil    TE   56.77  22.0
# 1      2     amit    TE   59.77  21.0
# 2      3   aniket    BE   76.88  19.0
# 3      4  ajinkya    TE   69.66  20.0
# 6      7     amar    BE   65.34  19.0
# 7      8    Amita    be   68.33  23.0
# 8      9     amol    TE   56.75  20.0
# 9      9     amol    TE   56.75  20.0
# 12    12    Sujay    TE   74.12  22.0
# 13    13  subhash    be   88.45  21.0
# 15    15  shalini    TE   63.45  20.0

# %% [markdown]
# Handling Missing values

# %%
df['marks '].fillna(df['marks '].median())
# Out:
# 0     56.770
# 1     59.770
# 2     76.880
# 3     69.660
# 4     63.280
# 5     64.395
# 6     65.340
# 7     68.330
# 8     56.750
# 9     56.750
# 10    78.660
# 11    64.395
# 12    74.120
# 13    88.450
# 14    59.330
# 15    63.450
# Name: marks , dtype: float64

# %%
df['age'].fillna(df['age'].mode()[0])
# Out:
# 0     22.0
# 1     21.0
# 2     19.0
# 3     20.0
# 4     20.0
# 5     20.0
# 6     19.0
# 7     23.0
# 8     20.0
# 9     20.0
# 10    20.0
# 11    23.0
# 12    22.0
# 13    21.0
# 14    21.0
# 15    20.0
# Name: age, dtype: float64

# %%
df.dropna()
# Out:
#     roll     name class  marks    age
# 0      1     anil    TE   56.77  22.0
# 1      2     amit    TE   59.77  21.0
# 2      3   aniket    BE   76.88  19.0
# 3      4  ajinkya    TE   69.66  20.0
# 6      7     amar    BE   65.34  19.0
# 7      8    Amita    be   68.33  23.0
# 8      9     amol    TE   56.75  20.0
# 9      9     amol    TE   56.75  20.0
# 12    12    Sujay    TE   74.12  22.0
# 13    13  subhash    be   88.45  21.0
# 15    15  shalini    TE   63.45  20.0

# %% [markdown]
# Transforming Data

# %%
df = pd.read_csv('Social_Network_Ads.csv')
x = df[['Age','EstimatedSalary']]
scaler = MinMaxScaler()
x_scaled = scaler.fit_transform(x)
x_scaled
# Out:
# array([[0.02380952, 0.02962963],
#        [0.4047619 , 0.03703704],
#        [0.19047619, 0.20740741],
#        [0.21428571, 0.31111111],
#        [0.02380952, 0.45185185],
#        [0.21428571, 0.31851852],
#        [0.21428571, 0.51111111],
#        [0.33333333, 1.        ],
#        [0.16666667, 0.13333333],
#        [0.4047619 , 0.37037037],
#        [0.19047619, 0.48148148],
#        [0.19047619, 0.27407407],
#        [0.04761905, 0.52592593],
#        [0.33333333, 0.02222222],
#        [0.        , 0.4962963 ],
#        [0.26190476, 0.48148148],
#        [0.69047619, 0.07407407],
#        [0.64285714, 0.08148148],
#        [0.66666667, 0.0962963 ],
#        [0.71428571, 0.1037037 ],
#        [0.64285714, 0.05185185],
#        [0.69047619, 0.25185185],
#        [0.71428571, 0.19259259],
#        [0.64285714, 0.05185185],
#        [0.66666667, 0.05925926],
#        [0.69047619, 0.03703704],
#        [0.73809524, 0.0962963 ],
#        [0.69047619, 0.11111111],
# ...

# %%
df
# Out:
#       User ID  Gender   Age  EstimatedSalary  Purchased
# 0    15624510    Male  19.0          19000.0          0
# 1    15810944    Male  35.0          20000.0          0
# 2    15668575  Female  26.0          43000.0          0
# 3    15603246  Female  27.0          57000.0          0
# 4    15804002    Male  19.0          76000.0          0
# ..        ...     ...   ...              ...        ...
# 395  15691863  Female  46.0          41000.0          1
# 396  15706071    Male  51.0          23000.0          1
# 397  15654296  Female  50.0          20000.0          1
# 398  15755018    Male  36.0          33000.0          0
# 399  15594041  Female  49.0          36000.0          1
#
# [400 rows x 5 columns]

# %%
df = pd.get_dummies(df, columns=['Purchased'])
df
# Out:
#       User ID  Gender   Age  EstimatedSalary  Purchased_0  Purchased_1
# 0    15624510    Male  19.0          19000.0         True        False
# 1    15810944    Male  35.0          20000.0         True        False
# 2    15668575  Female  26.0          43000.0         True        False
# 3    15603246  Female  27.0          57000.0         True        False
# 4    15804002    Male  19.0          76000.0         True        False
# ..        ...     ...   ...              ...          ...          ...
# 395  15691863  Female  46.0          41000.0        False         True
# 396  15706071    Male  51.0          23000.0        False         True
# 397  15654296  Female  50.0          20000.0        False         True
# 398  15755018    Male  36.0          33000.0         True        False
# 399  15594041  Female  49.0          36000.0        False         True
#
# [400 rows x 6 columns]

# %% [markdown]
# Data Integration

# %%
df_2 = pd.read_csv('Student_5.csv')
df_3 = pd.read_csv('student3.csv')

# %%
merged_data = pd.merge(df_2, df_3, on='roll')
merged_data
# Out:
#     roll   name_x class_x  marks _x  age_x   name_y class_y  marks _y  age_y
# 0      1     anil      TE     56.77   22.0     anil      TE     56.77   22.0
# 1      2     amit      TE     59.77   21.0     amit      TE     59.77   21.0
# 2      3   aniket      BE     76.88   19.0   aniket      BE     76.88   19.0
# 3      4  ajinkya      TE     69.66   20.0  ajinkya      TE     69.66   20.0
# 4      5     asha      TE     63.28    NaN     asha      TE     63.28    NaN
# 5      6   ayesha      BE       NaN   20.0   ayesha      BE       NaN   20.0
# 6      7     amar      BE     65.34   19.0     amar      BE     65.34   19.0
# 7      7     amar      BE     65.34   19.0     amar      BE     65.34   19.0
# 8      8    Amita      be    168.33   23.0    Amita      be     68.33   23.0
# 9      9     amol      TE     56.75   20.0     amol      TE     56.75   20.0
# 10     9     amol      TE     56.75   20.0     amol      TE     56.75   20.0
# ...
